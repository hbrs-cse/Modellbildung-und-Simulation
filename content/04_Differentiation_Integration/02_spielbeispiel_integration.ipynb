# %% [markdown]
# # Spielbeispiel: Integration

# %% [markdown]
# Hier finden Sie eine Demonstration verschiedener Integrationsverfahren zum "Herumspielen". **Die Darstellung in einem eigenen Tab ist sehr zu empfehlen.** Klicken Sie <a href="https://phispel-spielbeispiel-integration-streamlit-app-mcu82u.streamlit.app/" target="_blank">**hier**</a>, um die Seite in einem neuen Tab zu öffnen.

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <body margin = "0">
#
# <iframe src="https://phispel-spielbeispiel-integration-streamlit-app-mcu82u.streamlit.app/?embedded=true" width="100%" height="700" frameborder="0">
#   <p>Your browser does not support iframes.</p>
# </iframe>
#
# </body>
# </html>

# %% [markdown]
# <div style="text-align: left;font-size:80%;color:grey"> - Hinweis: Diese Seite ist von Streamlit eingebunden und unterliegt der dort angegebenen Lizenz! -
