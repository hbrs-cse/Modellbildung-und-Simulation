% %% [markdown]
% # Datenverarbeitung in MATLAB
%
% In diesem Videokurs lernen Sie einige Grundlagen zum Umgang mit Daten in MATLAB. Der Kurs vertieft viele Inhalte der Übungssammlung und kann die Erkenntnisse daraus gut ergänzen.

% %% [markdown]
% <iframe width="560" height="315" src="https://youtube.com/playlist?list=PLmClq2ZJ_PtuIEIJOpXwu0xQPwlzw3whv" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
